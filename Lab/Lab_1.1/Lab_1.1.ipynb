# %%
import matplotlib.pyplot as plt
import numpy as np  
import pandas as pd
import seaborn as sns

# %%
country= pd.read_csv('C:\\Users\\DELL\\Desktop\\Code\\Github\\MachineLearning_Ashutosh\\Lab\\Lab_1.1\\gapminderDataFiveYear.csv')

# %%
country.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
country=['France','Germany','United Kingdom','Italy','Spain']
country_df=pd.read_csv(r'C:\Users\DELL\Desktop\Code\Github\MachineLearning_Ashutosh\Lab\Lab_1.1\gapminderDataFiveYear.csv')

for country in country:
    data=country_df[country_df['country']==country]
    plt.plot(data['year'],data['lifeExp'],label=country)
plt.xlabel('Year')
plt.ylabel('Pop')
# Out:
# Text(0, 0.5, 'Pop')
