# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
value=pd.read_csv(r"C:\Users\DELL\Desktop\Code\Github\MachineLearning_Ashutosh\Lab\Lab_1.3\planets.csv")

# %%
value
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
value=value['mass'].dropna()

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
# Out:
# <Axes: >

# %%
plt.hist(value, bins=30, color='skyblue', edgecolor='black')
# Out:
# (array([211.,  81.,  66.,  37.,  22.,  11.,  11.,  11.,  12.,   8.,   5.,
#           8.,   7.,   3.,   2.,   1.,   3.,   3.,   2.,   0.,   1.,   2.,
#           1.,   2.,   1.,   1.,   0.,   0.,   0.,   1.]),
#  array([3.60000000e-03, 8.36813333e-01, 1.67002667e+00, 2.50324000e+00,
#         3.33645333e+00, 4.16966667e+00, 5.00288000e+00, 5.83609333e+00,
#         6.66930667e+00, 7.50252000e+00, 8.33573333e+00, 9.16894667e+00,
#         1.00021600e+01, 1.08353733e+01, 1.16685867e+01, 1.25018000e+01,
#         1.33350133e+01, 1.41682267e+01, 1.50014400e+01, 1.58346533e+01,
#         1.66678667e+01, 1.75010800e+01, 1.83342933e+01, 1.91675067e+01,
#         2.00007200e+01, 2.08339333e+01, 2.16671467e+01, 2.25003600e+01,
#         2.33335733e+01, 2.41667867e+01, 2.50000000e+01]),
#  <BarContainer object of 30 artists>)

# %%
plt.title("PLANET MASS DISTRIBUTION")   
plt.xlabel("MASS") 
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
plt.boxplot(value, vert=False)
plt.xlabel("MASS")
plt.title("count")      
plt.tight_layout()
plt.show()
